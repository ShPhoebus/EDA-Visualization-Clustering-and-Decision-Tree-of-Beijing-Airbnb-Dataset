# %%
import matplotlib.pyplot as plt
import pandas as  pd
import numpy as np
import seaborn as  sns
import csv
import seaborn as sb

# %%
path='listings.csv'#原始数据
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (34744, 106)

# %%
data.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  3.474400e+04  3.474400e+04            0.0         0.0             0.0
# mean   3.027304e+07  2.019092e+13            NaN         NaN             NaN
# std    7.417432e+06  6.457124e+00            NaN         NaN             NaN
# min    4.405400e+04  2.019092e+13            NaN         NaN             NaN
# 25%    2.578602e+07  2.019092e+13            NaN         NaN             NaN
# 50%    3.287639e+07  2.019092e+13            NaN         NaN             NaN
# 75%    3.606232e+07  2.019092e+13            NaN         NaN             NaN
# max    3.884381e+07  2.019092e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  3.474400e+04                   0.0         34743.000000
# mean   1.726389e+08                   NaN            12.179892
# std    8.130468e+07                   NaN            27.043761
# ...

# %%
data.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   44054   https://www.airbnb.com/rooms/44054  20190923212321   2019-09-24
# 1  100213  https://www.airbnb.com/rooms/100213  20190923212321   2019-09-23
# 2  114384  https://www.airbnb.com/rooms/114384  20190923212321   2019-09-23
# 3  114465  https://www.airbnb.com/rooms/114465  20190923212321   2019-09-23
# 4  114475  https://www.airbnb.com/rooms/114475  20190923212321   2019-09-23
#
#                                           name  \
# 0         Modern and Comfortable Living in CBD
# 1  The Great Wall Box Deluxe Suite A团园长城小院东院套房
# 2               Newly Remodeled Apt GUOMAO CBD
# 3             GUOMAO, CBD Comfy Convenient Apt
# 4                      Cozy Apt Central GUOMAO
#
#                                              summary  \
# 0  East Apartments offers comfortable living away...
# 1  This is your guide to live by the Great Wall! ...
# 2  华纳北京恋日公寓位于北京的中心商务区,是十分受到旅客欢迎的订房选择｡ 5.0 km之外便是市...
# ...

# %%
path='calendar.csv'#原始数据
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (12681641, 7)

# %%
data.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  1.268164e+07    1.268164e+07    1.268164e+07
# mean   3.027301e+07    3.117331e+00    2.974571e+04
# std    7.417342e+06    1.975040e+01    5.364786e+06
# min    4.405400e+04    1.000000e+00    1.000000e+00
# 25%    2.578443e+07    1.000000e+00    1.125000e+03
# 50%    3.287638e+07    1.000000e+00    1.125000e+03
# 75%    3.606228e+07    1.000000e+00    1.125000e+03
# max    3.884381e+07    1.000000e+03    1.000000e+09

# %%
data.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0    21803737  2019-09-24         f  $409.00        $409.00             1.0
# 1    21803777  2019-09-24         f  $459.00        $459.00             1.0
# 2    21803777  2019-09-25         f  $459.00        $459.00             1.0
# 3    21803777  2019-09-26         f  $459.00        $459.00             1.0
# 4    21803777  2019-09-27         f  $459.00        $459.00             1.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
path='reviews.csv'#原始数据
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (251128, 6)

# %%
data.describe()
# Out:
#          listing_id            id   reviewer_id
# count  2.511280e+05  2.511280e+05  2.511280e+05
# mean   2.408598e+07  3.674561e+08  1.549739e+08
# std    8.367367e+06  1.282201e+08  7.988677e+07
# min    4.405400e+04  8.474800e+04  1.000000e+00
# 25%    1.836875e+07  2.764966e+08  9.105609e+07
# 50%    2.477196e+07  4.115905e+08  1.553894e+08
# 75%    3.094333e+07  4.741778e+08  2.225413e+08
# max    3.881209e+07  5.352124e+08  2.969672e+08

# %%
data.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       44054    84748  2010-08-25       207019        Jarrod
# 1       44054   118384  2010-10-13       218723      Kimberly
# 2       44054   436978  2011-08-11       609177          Emma
# 3       44054  1118657  2012-04-12      1787536      Andreyna
# 4       44054  2140650  2012-08-30      1179565       Frances
#
#                                             comments
# 0  Sev was very helpful.  Sev showed us where to ...
# 1  We arrived in Beijing very early in the mornin...
# 2  It is a really massive apartment and really co...
# 3  Sev was incredibly helpful, showed us around t...
# 4  The appartment was ideal for our party of 6 ad...

# %%
path='decisiontree2.csv'#修改数据 用于显示属性之间的相关性
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (34744, 18)

# %%
data.corr()
# Out:
#                              host_is_superhost  host_identity_verified  \
# host_is_superhost                     1.000000                0.099205
# host_identity_verified                0.099205                1.000000
# accommodates                          0.042101                0.028249
# bathrooms                             0.049410                0.021532
# bedrooms                              0.049774                0.023490
# beds                                  0.051015                0.025070
# price                                 0.033270                0.003788
# extra_people                         -0.044282               -0.053384
# minimum_nights                        0.018131               -0.014929
# availability_30                       0.105321                0.091113
# number_of_reviews                    -0.329329               -0.178693
# review_scores_rating                 -0.172519               -0.028412
# ...

# %%
path='decisiontree3.csv'#修改数据 用于显示属性之间的关系的散点图
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (34744, 7)

# %%
sb.pairplot(data.iloc[0:1000,0:8].dropna())

# %%
path='decisiontree4.csv'#修改数据 用于显示属性之间的关系的散点图
data=pd.read_csv(path)

# %%
data.corr()
# Out:
#                       host_is_superhost  accommodates  bedrooms      beds  \
# host_is_superhost              1.000000      0.042101  0.049774  0.051015
# accommodates                   0.042101      1.000000  0.778337  0.765258
# bedrooms                       0.049774      0.778337  1.000000  0.734742
# beds                           0.051015      0.765258  0.734742  1.000000
# price                          0.033270      0.311013  0.284462  0.254719
# number_of_reviews             -0.329329     -0.067306 -0.070665 -0.065542
# review_scores_rating          -0.172519      0.007267  0.024120  0.003685
#
#                          price  number_of_reviews  review_scores_rating
# host_is_superhost     0.033270          -0.329329             -0.172519
# accommodates          0.311013          -0.067306              0.007267
# bedrooms              0.284462          -0.070665              0.024120
# beds                  0.254719          -0.065542              0.003685
# ...

# %%
sb.pairplot(data.iloc[0:1000].dropna())
